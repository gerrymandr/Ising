# %%
import networkx as nx
import numpy as np
import preprocessing as pre
from energy import sparse_capy
import ising
from tqdm import tqdm

# %%
config_file = 'sample_config.txt'
dual_graph, repvote, demvote, dists, pos, node_size = pre.get_data(config_file)

# %%
pre.draw_state(dual_graph, demvote, repvote, pos, node_size)

# %%
# get adjacency matrix 
A = nx.to_scipy_sparse_matrix(dual_graph)
sim = ising.ising(repvote, demvote, A, target=0.0, steps=100)

# %%
# %%time
i = 1
for repvote, demvote in tqdm(sim):
    i += 1
# Out:
# 0it [00:00, ?it/s]
# 10it [00:00, 84.86it/s]
# 20it [00:00, 90.20it/s]
# 30it [00:00, 90.91it/s]
# 38it [00:00, 88.38it/s]
# 47it [00:00, 88.65it/s]
# 58it [00:00, 90.85it/s]
# 68it [00:00, 92.07it/s]
# 78it [00:00, 92.74it/s]
# 88it [00:00, 92.08it/s]
# 97it [00:01, 91.32it/s]
# 100it [00:01, 88.94it/s]
# CPU times: user 1.08 s, sys: 38.2 ms, total: 1.12 s
# Wall time: 1.14 s

# %%
pre.draw_state(dual_graph, demvote, repvote, pos, node_size)

# %%
import importlib
importlib.reload(ising)
# Out:
# <module 'ising' from '/Users/marshallmueller/Desktop/vrdi2018/newIsing/Ising/real_world/ising.py'>

# %%
demvote
# Out:
# array([[1063.],
#        [ 238.],
#        [ 471.],
#        ...,
#        [   0.],
#        [ 284.],
#        [ 257.]])
